# %%
import pandas as pd

# %%
data = pd.read_csv("~/Downloads/uc_all.csv")

# %%
data
# Out:
#                              fullname          campus       city fall_term  \
# 0        BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# 1        BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# 2        BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# 3        BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# 4        BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# ...                               ...             ...        ...       ...
# 2336278  BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# 2336279  BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# 2336280  BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# 2336281  BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
# 2336282  BELLA VISTA HIGH SCHOOL50912  Universitywide  Fair Oaks  2005-9-1
#
# ...
